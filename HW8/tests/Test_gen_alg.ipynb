# %%
from gen_alg import *

# %% [markdown]
# # 1 - [6, 0]

# %%
genetic_algorithm('-2*x1 + 8*x2', ['-x1 - 2*x2 >= -16', '-6*x1 - 2*x2 >= 40'], -0.1)
# Out:
# [-4.659703566171913, -9.959903309402907]

# %% [markdown]
# # 2 - [1, 1]

# %%
genetic_algorithm('x1 + x2', ['-x1 + 2*x2 >= 0', 'x1 - x2 >= -1', 'x1 - 0*x2 >= 0.75'], 1.5)
# Out:
# [0.790549135069833, 0.43068560342764783]

# %% [markdown]
# # 3 - [2, 1]

# %%
genetic_algorithm('-2*x1 + x2', ['-x1 + 2*x2 >= 0', 'x1 - x2 >= -1', '-x1 - x2 >= -3.2'], 2) # если последнее условие
                                                                                                     # убрать, то не имеет 
                                                                                                     # допустимых решений
# Out:
# [2.0706997233338917, 1.0504504239225536]

# %% [markdown]
# # 4 - [1, 4]

# %%
genetic_algorithm('-10*x1 - x2', ['-x1 + 0.5*x2 >= 1', '-2*x1 - x2 >= -6'], -1.5)
# Out:
# [0.8028100277461654, 3.663519668440351]

# %% [markdown]
# # 5 - [0, 0]

# %%
genetic_algorithm('3*x1 + x2', ['-x1 - x2 >= -3.5', '-x1 - 0*x2 >= -2.25', '0*x1 - x2 >= -3'], 0.000000000001)
# Out:
# [-9.977446672933679, -9.074055053274057]

# %% [markdown]
# # 6 - [1, 3]

# %%
genetic_algorithm('-2*x1 - 4*x2', ['-2*x1 - x2 >= -6.4', '-x1 - 3*x2 >= -10'], 3)
# Out:
# [1.4901376848945507, 2.7660882155874376]

# %% [markdown]
# # 7 - [1, 3]

# %%
genetic_algorithm('x1 - x2', ['x1 - 0.5*x2 >= -0.5', '-2*x1 - x2 >= -6'], 6)
# Out:
# [1.3908970088126633, 3.126216340511487]

# %% [markdown]
# # 8 - [2, 0]

# %%
genetic_algorithm('-10*x1 - x2', ['-4*x1 - 5*x2 >= -20', 'x1 - 0.5*x2 >= -1', '-0.5*x1 + x2 >= -1'], 6)
# Out:
# [3.6595807837245893, 1.0598071424322857]

# %% [markdown]
# # 9 - [3, 1]

# %%
genetic_algorithm('-3*x1 - 2*x2', ['x1 - 2*x2 >= -4', '-3*x1 - 5*x2 >= -15', '-x1 + x2 >= -3'], 15)
# Out:
# [3.4223849830638002, 0.7378641958378669]

# %% [markdown]
# # 10 - [0, 7]

# %%
genetic_algorithm('x1 - x2', ['-x1 + 2*x2 >= 4', '-3*x1 - 2*x2 >= -14'], -1)
# Out:
# [-9.977624621031946, 9.647005794471255]
