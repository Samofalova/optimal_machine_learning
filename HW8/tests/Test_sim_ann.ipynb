# %%
from sim_ann import *

# %% [markdown]
# # 1 - [6, 0]

# %%
simulated_annealing(F='-2*x1 + 8*x2', constraints=['x1 + 2*x2 <= 16', '6*x1 + 2*x2 <= 40', '-x1 + 0*x2 <= -4', '0*x1 - x2 <= 1'], start_points=[5, 2])
# Out:
# array([5.74691081838162, -0.987643273526490], dtype=object)

# %% [markdown]
# # 2 - [1, 1]

# %%
simulated_annealing(F='x1 + x2', constraints=['x1 - 2*x2 <= 0', '-x1 + x2 <= 1', '-x1 + 0*x2 <= -1'], start_points=[1, 1])
# Out:
# array([1.00090669593094, 1.00090669593094], dtype=object)

# %% [markdown]
# # 3 - [2, 1]

# %%
simulated_annealing(F='-2*x1 + x2', constraints=['x1 - 2*x2 <= 0', '-x1 + x2 <= 1', 'x1 + x2 <= 4'], start_points=[1.5, 1])              # если последнее условие
                                                                                                                                         # убрать, то не имеет 
                                                                                                                                         # допустимых решений
# Out:
# array([1.74919292748946, 0.875403536255268], dtype=object)

# %% [markdown]
# # 4 - [1, 4]

# %%
simulated_annealing(F='-10*x1 - x2', constraints=['x1 - 0.5*x2 <= -1', '2*x1 + x2 <= 6'], start_points=[0.5, 3.5])
# Out:
# array([0.758670394465514, 3.52586703944655], dtype=object)

# %% [markdown]
# # 5 - [0, 0]

# %%
simulated_annealing(F='3*x1 + x2', constraints=['x1 + x2 <= 3.5', 'x1 + 0*x2 <= 2.25', '0*x1 + x2 <= 3'], start_points=[0, 2])
# Out:
# array([-7.10260566439669, -0.367535221465569], dtype=object)

# %% [markdown]
# # 6 - [1, 3]

# %%
simulated_annealing(F='-2*x1 - 4*x2', constraints=['2*x1 + x2 <= 6.4', 'x1 + 3*x2 <= 10'], start_points=[0, 2])
# Out:
# array([0.568887466078388, 3.13777493215677], dtype=object)

# %% [markdown]
# # 7 - [1, 3]

# %%
simulated_annealing(F='x1 - x2', constraints=['-x1 + 0.5*x2 <= 0.5', '2*x1 + x2 <= 6'], start_points=[1, 2])
# Out:
# array([0.668382018881817, 2.33161798111818], dtype=object)

# %% [markdown]
# # 8 - [2, 0]

# %%
simulated_annealing(F='-10*x1 - x2', constraints=['4*x1 + 5*x2 <= 20', '-x1 + 0.5*x2 <= 1', '0.5*x1 - x2 <= 1'], start_points=[0, 0])
# Out:
# array([2.49890396926026, 0.249890396926026], dtype=object)

# %% [markdown]
# # 9 - [3, 1]

# %%
simulated_annealing(F='-3*x1 - 2*x2', constraints=['-x1 + 2*x2 <= 4', '3*x1 + 5*x2 <= 15', 'x1 - x2 <= 3'], start_points=[2, 0])
# Out:
# array([3.41865161091924, 0.945767740612826], dtype=object)

# %% [markdown]
# # 10 - [0, 7]

# %%
simulated_annealing(F='x1 - x2', constraints=['x1 - 2*x2 <= -4', '3*x1 + 2*x2 <= 14'], start_points=[2, 4])
# Out:
# array([-2.12984345702590, 8.12984345702592], dtype=object)
