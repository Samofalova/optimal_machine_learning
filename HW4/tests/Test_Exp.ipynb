# %%
from regression import *

# %% [markdown]
# #### 1. x разные, y = const (точки располагаются на прямой, параллельной оси OX)
# #### A0 = y = const, a1, a2… = 0 (или оооочень маленькое число)

# %%
data = pd.read_excel('Data.xlsx', sheet_name = '1')
data.head(3)
# Out:
#       Y     X1     X2     X3     X4     X5
# 0  16.4 -48.07  59.76 -80.29  99.53  83.74
# 1  16.4  70.02 -14.37 -25.18  40.82  53.19
# 2  16.4  11.54  94.68 -60.22  89.67  69.94

# %%
X, y = data[['X1', 'X2']], data['Y']
res = exp_regression(X, y, regularization = 'Student', draw=True)
res
# Out:
# {'func': '16.4 * exp(0.0*x2) * exp(0.0*x1)',
#  'weights': array([0., 0.]),
#  'bias': 16.400000000000002}

# %%
X, y = data[['X1', 'X2', 'X3']], data['Y']
res = exp_regression(X, y, regularization = 'L1', draw=True)
res
# Out:
# К сожалению, мы не можем построить график, так как размерность пространства признаков велика.
# {'func': '16.4 * exp(0.0*x0)', 'weights': 0.0, 'bias': 16.40000000000001}

# %%
X, y = data[['X1', 'X4', 'X5', 'X3']], data['Y']
res = exp_regression(X, y, regularization = 'L2', draw=True)
res
# Out:
# К сожалению, мы не можем построить график, так как размерность пространства признаков велика.
# {'func': '16.4 * exp(0.0*x0)',
#  'weights': 3.8847544432574884e-35,
#  'bias': 16.40000000000001}

# %%
X, y = data[['X1', 'X2', 'X3', 'X4', 'X5']], data['Y']
res = exp_regression(X, y, draw=True)
res
# Out:
# К сожалению, мы не можем построить график, так как размерность пространства признаков велика.
# {'func': '16.4 * exp(-0.0*x0)',
#  'weights': -1.7761327409946875e-34,
#  'bias': 16.40000000000001}

# %%
res = exp_regression(X.iloc[:, 1], y, regularization = 'L1', draw=True)
res
# Out:
# {'func': '16.4 * exp(0.0*x0)', 'weights': 0.0, 'bias': 16.40000000000001}

# %%
res = exp_regression(X.iloc[:, 4], y, regularization = 'L2', draw=True)
res
# Out:
# {'func': '16.4 * exp(-0.0*x0)',
#  'weights': -2.1564993048707263e-33,
#  'bias': 16.40000000000001}

# %%
res = exp_regression(X.iloc[:, 2], y, regularization = 'Student', draw=True)
res
# Out:
# {'func': '16.4 * exp(0.0*x0)', 'weights': 0.0, 'bias': 16.400000000000002}

# %%
res = exp_regression(X.iloc[:, 3], y, draw=True)
res
# Out:
# {'func': '16.4 * exp(0.0*x0)',
#  'weights': 3.951385779496203e-34,
#  'bias': 16.40000000000001}

# %% [markdown]
# #### 2. x = const, y = const

# %%
data = pd.read_excel('Data.xlsx', sheet_name = '2')
data.head(3)
# Out:
#        Y  X1     X2  X3   X4   X5
# 0  91.19   0  158.6  13 -648 -7.5
# 1  91.19   0  158.6  13 -648 -7.5
# 2  91.19   0  158.6  13 -648 -7.5

# %%
X, y = data[['X1', 'X2']], data['Y']
res = exp_regression(X, y, regularization = 'Student', draw=True)
res
# Out:
# {'func': '91.19 * exp(0.0*x2) * exp(0.0*x1)',
#  'weights': array([0., 0.]),
#  'bias': 91.18999999999998}

# %%
X, y = data[['X1', 'X2', 'X3']], data['Y']
res = exp_regression(X, y, regularization = 'L1', draw=True)
res
# Out:
# К сожалению, мы не можем построить график, так как размерность пространства признаков велика.
# C:\Users\ACer\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
#   model = cd_fast.enet_coordinate_descent(
# {'func': '91.19 * exp(0.0*x0)', 'weights': 0.0, 'bias': 91.18999999999998}

# %%
X, y = data[['X1', 'X4', 'X5', 'X3']], data['Y']
res = exp_regression(X, y, regularization = 'L2', draw=True)
res
# Out:
# К сожалению, мы не можем построить график, так как размерность пространства признаков велика.
# {'func': '91.19 * exp(0.0*x0)', 'weights': 0.0, 'bias': 91.18999999999998}

# %%
X, y = data[['X1', 'X2', 'X4']], data['Y']
res = exp_regression(X, y, draw=True)
res
# Out:
# ---------------------------------------------------------------------------
# LinearlyDependent                         Traceback (most recent call last)
# <ipython-input-16-3b71317145bf> in <module>
#       1 X, y = data[['X1', 'X2', 'X4']], data['Y']
# ----> 2 res = exp_regression(X, y, draw=True)
#       3 res
#
# ~\Downloads\Aksen\regression.py in exp_regression(X, y, tol, regularization, alpha, draw, n_point)
#      94     if regularization is None:
#      95         if X.shape[1] >= 2 and np.linalg.det(X.T @ X) == 0:
# ---> 96             raise LinearlyDependent
#      97         reg = LinearRegression().fit(X, y_new)
#      98     elif regularization == 'L1':
#
# LinearlyDependent: Присутствуют линейно зависимые признаки. Мы не можем применить МНК.

# %%
X, y = data[['X1', 'X2', 'X3', 'X4', 'X5']], data['Y']

# %%
res = exp_regression(X.iloc[:, 1], y, regularization = 'L1', draw=True)
res
# Out:
# C:\Users\ACer\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
#   model = cd_fast.enet_coordinate_descent(
# {'func': '91.19 * exp(0.0*x0)', 'weights': 0.0, 'bias': 91.18999999999998}

# %%
res = exp_regression(X.iloc[:, 4], y, regularization = 'L2', draw=True)
res
# Out:
# {'func': '91.19 * exp(0.0*x0)', 'weights': 0.0, 'bias': 91.18999999999998}

# %%
res = exp_regression(X.iloc[:, 2], y, regularization = 'Student', draw=True)
res
# Out:
# {'func': '91.19 * exp(0.0*x0)', 'weights': 0.0, 'bias': 91.18999999999998}

# %%
res = exp_regression(X.iloc[:, 3], y, draw=True)
res
# Out:
# {'func': '91.19 * exp(0.0*x0)', 'weights': 0.0, 'bias': 91.18999999999998}

# %% [markdown]
# #### 3. x1 = const1, x2=const2, … y разные

# %%
data = pd.read_excel('Data.xlsx', sheet_name = '3')
data.head(3)
# Out:
#       Y1     Y2     Y3     Y4     Y5  X1     X2  X3   X4   X5
# 0 -28.69  55.08 -95.87  67.80  82.67   0  158.6  13 -648 -7.5
# 1 -47.12 -33.52 -94.66  97.54  31.79   0  158.6  13 -648 -7.5
# 2  51.55 -84.48   8.87  81.46   7.50   0  158.6  13 -648 -7.5

# %%
X, y = data[['X1', 'X2']], data['Y4']
res = exp_regression(X, y, regularization = 'Student', draw=True)
res
# Out:
# {'func': '51.28317 * exp(0.0*x2) * exp(0.0*x1)',
#  'weights': array([0., 0.]),
#  'bias': 51.2831683424629}

# %%
X, y = data[['X1', 'X2', 'X3']], data['Y5']
res = exp_regression(X, y, regularization = 'L1', draw=True)
res
# Out:
# К сожалению, мы не можем построить график, так как размерность пространства признаков велика.
# {'func': '33.88537 * exp(0.0*x0)', 'weights': 0.0, 'bias': 33.88536528363284}

# %%
X, y = data[['X1', 'X4', 'X5', 'X3']], data['Y4']
res = exp_regression(X, y, regularization = 'L2', draw=True)
res
# Out:
# К сожалению, мы не можем построить график, так как размерность пространства признаков велика.
# {'func': '51.28317 * exp(0.0*x0)', 'weights': 0.0, 'bias': 51.2831683424629}

# %%
X, y = data[['X1', 'X2', 'X4']], data['Y5']
res = exp_regression(X, y, draw=True)
res
# Out:
# ---------------------------------------------------------------------------
# LinearlyDependent                         Traceback (most recent call last)
# <ipython-input-26-735c904df1f1> in <module>
#       1 X, y = data[['X1', 'X2', 'X4']], data['Y5']
# ----> 2 res = exp_regression(X, y, draw=True)
#       3 res
#
# ~\Downloads\Aksen\regression.py in exp_regression(X, y, tol, regularization, alpha, draw, n_point)
#      94     if regularization is None:
#      95         if X.shape[1] >= 2 and np.linalg.det(X.T @ X) == 0:
# ---> 96             raise LinearlyDependent
#      97         reg = LinearRegression().fit(X, y_new)
#      98     elif regularization == 'L1':
#
# LinearlyDependent: Присутствуют линейно зависимые признаки. Мы не можем применить МНК.

# %%
X, y = data[['X1', 'X2', 'X3', 'X4', 'X5']], data['Y4']

# %%
res = exp_regression(X.iloc[:, 1], y, regularization = 'L1', draw=True)
res
# Out:
# {'func': '51.28317 * exp(0.0*x0)', 'weights': 0.0, 'bias': 51.2831683424629}

# %%
res = exp_regression(X.iloc[:, 4], y, regularization = 'L2', draw=True)
res
# Out:
# {'func': '51.28317 * exp(0.0*x0)', 'weights': 0.0, 'bias': 51.2831683424629}

# %%
res = exp_regression(X.iloc[:, 2], y, regularization = 'Student', draw=True)
res
# Out:
# {'func': '51.28317 * exp(0.0*x0)', 'weights': 0.0, 'bias': 51.2831683424629}

# %%
res = exp_regression(X.iloc[:, 3], y, draw=True)
res
# Out:
# {'func': '51.28317 * exp(0.0*x0)', 'weights': 0.0, 'bias': 51.2831683424629}

# %% [markdown]
# #### 4. x1 = const, x2 – разные, y разные

# %%
data = pd.read_excel('Data.xlsx', sheet_name = '4')
data.head(3)
# Out:
#       Y1     Y2  X1     X2     X3     X4     X5
# 0  60.92  59.18  13 -14.34  68.68  37.90  82.97
# 1 -24.22  87.58  13 -44.93  88.31  59.27  46.96
# 2 -38.91  45.72  13 -49.24 -55.98  29.60  28.19

# %%
X, y = data[['X1', 'X2']], data['Y2']
res = exp_regression(X, y, regularization = 'Student', draw=True)
res
# Out:
# {'func': '42.28708 * exp(0.0*x2) * exp(-0.01819*x1)',
#  'weights': array([ 0.       , -0.0181923]),
#  'bias': 42.28708448215591}

# %%
X, y = data[['X1', 'X2', 'X3']], data['Y2']
res = exp_regression(X, y, regularization = 'L1', draw=True)
res
# Out:
# К сожалению, мы не можем построить график, так как размерность пространства признаков велика.
# {'func': '38.19834 * exp(0.0*x0)', 'weights': 0.0, 'bias': 38.198343634290346}

# %%
X, y = data[['X1', 'X4', 'X5', 'X3']], data['Y2']
res = exp_regression(X, y, regularization = 'L2', draw=True)
res
# Out:
# К сожалению, мы не можем построить график, так как размерность пространства признаков велика.
# {'func': '21.50318 * exp(0.0*x0)', 'weights': 0.0, 'bias': 21.503177485540366}

# %%
X, y = data[['X1', 'X2', 'X4']], data['Y2']
res = exp_regression(X, y, draw=True)
res
# Out:
# К сожалению, мы не можем построить график, так как размерность пространства признаков велика.
# {'func': '31.55391 * exp(0.0*x0)', 'weights': 0.0, 'bias': 31.553906378124232}

# %%
X, y = data[['X1', 'X2', 'X3', 'X4', 'X5']], data['Y2']

# %%
res = exp_regression(X.iloc[:, 1], y, regularization = 'L1', draw=True)
res
# Out:
# {'func': '37.14235 * exp(-0.00106*x0)',
#  'weights': -0.001063905747436459,
#  'bias': 37.142349938471796}

# %%
res = exp_regression(X.iloc[:, 1], y, regularization = 'L2', draw=True)
res
# Out:
# {'func': '37.24323 * exp(-0.00142*x0)',
#  'weights': -0.0014244129959243416,
#  'bias': 37.24322764439126}

# %%
res = exp_regression(X.iloc[:, 1], y, regularization = 'Student', draw=True)
res
# Out:
# {'func': '42.28708 * exp(-0.01819*x0)',
#  'weights': -0.018192303417257912,
#  'bias': 42.28708448215591}

# %%
res = exp_regression(X.iloc[:, 1], y, draw=True)
res
# Out:
# {'func': '37.24323 * exp(-0.00142*x0)',
#  'weights': -0.0014244295615632504,
#  'bias': 37.24323228610388}

# %% [markdown]
# #### 5. Точки соответствуют регрессии

# %%
data = pd.read_excel('Data.xlsx', sheet_name = '7э')
data.head(3)
# Out:
#           Y1            Y2        Y3  X1  X2  X3
# 0  12.000000  1.262640e+19  0.030472   0 -73 -26
# 1  32.619382  6.929515e+18  0.030435   1 -72 -24
# 2  88.668673  3.802999e+18  0.030399   2 -71 -22

# %%
X, y = data[['X1', 'X2', 'X3']], data['Y1']

# %%
res = exp_regression(X.iloc[:, 0], y, regularization = 'L1', draw=True)
res
# Out:
# {'func': '13.94201 * exp(0.99211*x0)',
#  'weights': 0.9921052631578947,
#  'bias': 13.942010912739297}

# %%
X, y = data[['X1', 'X2', 'X3']], data['Y2']

# %%
res = exp_regression(X.iloc[:, 1], y, regularization = 'L2', draw=True)
res
# Out:
# {'func': '1.20789 * exp(-0.59988*x0)',
#  'weights': -0.5998785670916816,
#  'bias': 1.207894708460246}

# %%
X, y = data[['X1', 'X2', 'X3']], data['Y3']

# %%
res = exp_regression(X.iloc[:, 2], y, regularization = 'Student', draw=True)
res
# Out:
# ---------------------------------------------------------------------------
# InsufficientData                          Traceback (most recent call last)
# <ipython-input-48-16d84a954975> in <module>
#       1 # не может быть О_о
# ----> 2 res = exp_regression(X.iloc[:, 2], y, regularization = 'Student', draw=True)
#       3 res
#
# ~\Downloads\Aksen\regression.py in exp_regression(X, y, tol, regularization, alpha, draw, n_point)
#     103         X_new, y_log_new = student_del(pd.DataFrame(X),
#     104                                        pd.DataFrame(y_new))
# --> 105         check_data(X_new)
#     106         if len(X_new.shape) < 2:
#     107             X_new = X_new.to_numpy().reshape(-1, 1)
#
# ~\Downloads\Aksen\regression.py in check_data(X)
#      55     else:
#      56         if len(X) < 10:
# ---> 57             raise InsufficientData
#      58
#      59
#
# ...

# %%
res = exp_regression(X.iloc[:, 2], y, draw=True)
res
# Out:
# {'func': '0.03 * exp(-0.0006*x0)',
#  'weights': -0.0006000000000000002,
#  'bias': 0.03000000000000001}

# %% [markdown]
# #### Окружность....

# %%
data = pd.read_excel('Data.xlsx', sheet_name = '8о')
data.head(3)
# Out:
#          Y1        Y2   X1
# 0  0.000000  5.000000 -4.0
# 1 -1.936492  3.063508 -3.5
# 2  1.936492  6.936492 -3.5

# %%
X, y = data['X1'], data['Y2']

# %%
res = exp_regression(X, y, regularization = 'L1', draw=True)
res
# Out:
# {'func': '3.69043 * exp(0.0*x0)', 'weights': 0.0, 'bias': 3.6904292548091373}

# %%
res = exp_regression(X, y, regularization = 'L2', draw=True)
res
# Out:
# {'func': '3.69043 * exp(0.0*x0)',
#  'weights': 2.5669896523125005e-18,
#  'bias': 3.6904292548091373}

# %%
res = exp_regression(X, y, regularization = 'Student', draw=True)
res
# Out:
# ---------------------------------------------------------------------------
# InsufficientData                          Traceback (most recent call last)
# <ipython-input-54-7df74db03798> in <module>
# ----> 1 res = exp_regression(X, y, regularization = 'Student', draw=True)
#       2 res
#
# ~\Downloads\Aksen\regression.py in exp_regression(X, y, tol, regularization, alpha, draw, n_point)
#     103         X_new, y_log_new = student_del(pd.DataFrame(X),
#     104                                        pd.DataFrame(y_new))
# --> 105         check_data(X_new)
#     106         if len(X_new.shape) < 2:
#     107             X_new = X_new.to_numpy().reshape(-1, 1)
#
# ~\Downloads\Aksen\regression.py in check_data(X)
#      55     else:
#      56         if len(X) < 10:
# ---> 57             raise InsufficientData
#      58
#      59
#
# InsufficientData: Данных недостаточно. Их должно быть не менее 2^k строк, где k – количество признаков. Если признак 1, то хотя бы 10 строк.

# %%
res = exp_regression(X, y, draw=True)
res
# Out:
# {'func': '3.69043 * exp(0.0*x0)',
#  'weights': 6.144770431000436e-18,
#  'bias': 3.6904292548091373}
