# %%
from regression import *

# %% [markdown]
# #### 1. x разные, y = const (точки располагаются на прямой, параллельной оси OX)
# #### A0 = y = const, a1, a2… = 0 (или оооочень маленькое число)

# %%
data = pd.read_excel('Data.xlsx', sheet_name = '1')
data.head(3)
# Out:
#       Y     X1     X2     X3     X4     X5
# 0  16.4 -48.07  59.76 -80.29  99.53  83.74
# 1  16.4  70.02 -14.37 -25.18  40.82  53.19
# 2  16.4  11.54  94.68 -60.22  89.67  69.94

# %%
X, y = data[['X1', 'X2']], data['Y']
res = lin_regression(X, y, regularization = 'Student', draw=True)
res
# Out:
# {'func': '16.4 + 0.0x1 -0.0x2',
#  'weights': array([ 2.19795329e-33, -1.16294549e-32]),
#  'bias': 16.400000000000002}

# %%
X, y = data[['X1', 'X2', 'X3']], data['Y']
res = lin_regression(X, y, regularization = 'L1', draw=True)
res
# Out:
# К сожалению, мы не можем построить график, так как размерность пространства признаков велика.
# C:\Users\ACer\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
#   model = cd_fast.enet_coordinate_descent(
# {'func': '16.4 + 0.0x1 + 0.0x2 + 0.0x3',
#  'weights': array([0., 0., 0.]),
#  'bias': 16.4}

# %%
X, y = data[['X1', 'X4', 'X5', 'X3']], data['Y']
res = lin_regression(X, y, regularization = 'L2', draw=True)
res
# Out:
# К сожалению, мы не можем построить график, так как размерность пространства признаков велика.
# {'func': '16.4 + 0.0x1 + 0.0x2 + 0.0x3 + 0.0x4',
#  'weights': array([0., 0., 0., 0.]),
#  'bias': 16.4}

# %%
X, y = data[['X1', 'X2', 'X3', 'X4', 'X5']], data['Y']
res = lin_regression(X, y, draw=True)
res
# Out:
# К сожалению, мы не можем построить график, так как размерность пространства признаков велика.
# {'func': '16.4 + 0.0x1 + 0.0x2 + 0.0x3 + 0.0x4 + 0.0x5',
#  'weights': array([0., 0., 0., 0., 0.]),
#  'bias': 16.4}

# %%
res = lin_regression(X.iloc[:, 1], y, regularization = 'L1', draw=True)
res
# Out:
# C:\Users\ACer\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
#   model = cd_fast.enet_coordinate_descent(
# {'func': '16.4 + 0.0x1', 'weights': array([0.]), 'bias': 16.4}

# %%
res = lin_regression(X.iloc[:, 4], y, regularization = 'L2', draw=True)
res
# Out:
# {'func': '16.4 + 0.0x1', 'weights': array([0.]), 'bias': 16.4}

# %%
res = lin_regression(X.iloc[:, 2], y, regularization = 'Student', draw=True)
res
# Out:
# {'func': '16.4 + 0.0x1', 'weights': array([0.]), 'bias': 16.4}

# %%
res = lin_regression(X.iloc[:, 3], y, draw=True)
res
# Out:
# {'func': '16.4 -0.0x1', 'weights': array([-0.]), 'bias': 16.4}

# %% [markdown]
# #### 2. x = const, y = const

# %%
data = pd.read_excel('Data.xlsx', sheet_name = '2')
data.head(3)
# Out:
#        Y  X1     X2  X3   X4   X5
# 0  91.19   0  158.6  13 -648 -7.5
# 1  91.19   0  158.6  13 -648 -7.5
# 2  91.19   0  158.6  13 -648 -7.5

# %%
X, y = data[['X1', 'X2']], data['Y']
res = lin_regression(X, y, regularization = 'Student', draw=True)
res
# Out:
# {'func': '91.19 + 0.0x1 + 0.0x2', 'weights': array([0., 0.]), 'bias': 91.19}

# %%
X, y = data[['X1', 'X2', 'X3']], data['Y']
res = lin_regression(X, y, regularization = 'L1', draw=True)
res
# Out:
# К сожалению, мы не можем построить график, так как размерность пространства признаков велика.
# C:\Users\ACer\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
#   model = cd_fast.enet_coordinate_descent(
# {'func': '91.19 + 0.0x1 + 0.0x2 + 0.0x3',
#  'weights': array([0., 0., 0.]),
#  'bias': 91.19}

# %%
X, y = data[['X1', 'X4', 'X5', 'X3']], data['Y']
res = lin_regression(X, y, regularization = 'L2', draw=True)
res
# Out:
# К сожалению, мы не можем построить график, так как размерность пространства признаков велика.
# {'func': '91.19 + 0.0x1 + 0.0x2 + 0.0x3 + 0.0x4',
#  'weights': array([0., 0., 0., 0.]),
#  'bias': 91.19}

# %%
X, y = data[['X1', 'X2', 'X4']], data['Y']
res = lin_regression(X, y, draw=True)
res
# Out:
# К сожалению, мы не можем построить график, так как размерность пространства признаков велика.
# {'func': '91.19 + 0.0x1 + 0.0x2 + 0.0x3',
#  'weights': array([0., 0., 0.]),
#  'bias': 91.19}

# %%
X, y = data[['X1', 'X2', 'X3', 'X4', 'X5']], data['Y']

# %%
res = lin_regression(X.iloc[:, 1], y, regularization = 'L1', draw=True)
res
# Out:
# C:\Users\ACer\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
#   model = cd_fast.enet_coordinate_descent(
# {'func': '91.19 + 0.0x1', 'weights': array([0.]), 'bias': 91.19}

# %%
res = lin_regression(X.iloc[:, 4], y, regularization = 'L2', draw=True)
res
# Out:
# {'func': '91.19 + 0.0x1', 'weights': array([0.]), 'bias': 91.19}

# %%
res = lin_regression(X.iloc[:, 2], y, regularization = 'Student', draw=True)
res
# Out:
# {'func': '91.19 + 0.0x1', 'weights': array([0.]), 'bias': 91.19}

# %%
res = lin_regression(X.iloc[:, 3], y, draw=True)
res
# Out:
# {'func': '91.19 + 0.0x1', 'weights': array([0.]), 'bias': 91.19}

# %% [markdown]
# #### 3. x1 = const1, x2=const2, … y разные

# %%
data = pd.read_excel('Data.xlsx', sheet_name = '3')
data.head(3)
# Out:
#       Y1     Y2     Y3     Y4     Y5  X1     X2  X3   X4   X5
# 0 -28.69  55.08 -95.87  67.80  82.67   0  158.6  13 -648 -7.5
# 1 -47.12 -33.52 -94.66  97.54  31.79   0  158.6  13 -648 -7.5
# 2  51.55 -84.48   8.87  81.46   7.50   0  158.6  13 -648 -7.5

# %%
X, y = data[['X1', 'X2']], data['Y1']
res = lin_regression(X, y, regularization = 'Student', draw=True)
res
# Out:
# {'func': '13.5956 + 0.0x1 + 0.0x2',
#  'weights': array([0., 0.]),
#  'bias': 13.5956}

# %%
X, y = data[['X1', 'X2', 'X3']], data['Y2']
res = lin_regression(X, y, regularization = 'L1', draw=True)
res
# Out:
# К сожалению, мы не можем построить график, так как размерность пространства признаков велика.
# {'func': '-20.4108 + 0.0x1 + 0.0x2 + 0.0x3',
#  'weights': array([0., 0., 0.]),
#  'bias': -20.4108}

# %%
X, y = data[['X1', 'X4', 'X5', 'X3']], data['Y4']
res = lin_regression(X, y, regularization = 'L2', draw=True)
res
# Out:
# К сожалению, мы не можем построить график, так как размерность пространства признаков велика.
# {'func': '58.5084 + 0.0x1 + 0.0x2 + 0.0x3 + 0.0x4',
#  'weights': array([0., 0., 0., 0.]),
#  'bias': 58.508399999999995}

# %%
X, y = data[['X1', 'X2', 'X4']], data['Y5']
res = lin_regression(X, y, draw=True)
res
# Out:
# К сожалению, мы не можем построить график, так как размерность пространства признаков велика.
# {'func': '48.9204 + 0.0x1 + 0.0x2 + 0.0x3',
#  'weights': array([0., 0., 0.]),
#  'bias': 48.920399999999994}

# %%
X, y = data[['X1', 'X2', 'X3', 'X4', 'X5']], data['Y4']

# %%
res = lin_regression(X.iloc[:, 1], y, regularization = 'L1', draw=True)
res
# Out:
# {'func': '58.5084 + 0.0x1', 'weights': array([0.]), 'bias': 58.508399999999995}

# %%
X, y = data[['X1', 'X2', 'X3', 'X4', 'X5']], data['Y3']

# %%
res = lin_regression(X.iloc[:, 4], y, regularization = 'L2', draw=True)
res
# Out:
# {'func': '1.0644 + 0.0x1', 'weights': array([0.]), 'bias': 1.0644}

# %%
X, y = data[['X1', 'X2', 'X3', 'X4', 'X5']], data['Y1']

# %%
res = lin_regression(X.iloc[:, 2], y, regularization = 'Student', draw=True)
res
# Out:
# {'func': '13.5956 + 0.0x1', 'weights': array([0.]), 'bias': 13.5956}

# %%
X, y = data[['X1', 'X2', 'X3', 'X4', 'X5']], data['Y2']

# %%
res = lin_regression(X.iloc[:, 3], y, draw=True)
res
# Out:
# {'func': '-20.4108 + 0.0x1', 'weights': array([0.]), 'bias': -20.4108}

# %% [markdown]
# #### 4. x1 = const, x2 – разные, y разные

# %%
data = pd.read_excel('Data.xlsx', sheet_name = '4')
data.head(3)
# Out:
#       Y1     Y2  X1     X2     X3     X4     X5
# 0  60.92  59.18  13 -14.34  68.68  37.90  82.97
# 1 -24.22  87.58  13 -44.93  88.31  59.27  46.96
# 2 -38.91  45.72  13 -49.24 -55.98  29.60  28.19

# %%
X, y = data[['X1', 'X2']], data['Y2']
res = lin_regression(X, y, regularization = 'Student', draw=True)
res
# Out:
# {'func': '59.81413 + 0.0x1 -0.47551x2',
#  'weights': array([ 0.        , -0.47551386]),
#  'bias': 59.814133177561715}

# %%
X, y = data[['X1', 'X2', 'X3']], data['Y1']
res = lin_regression(X, y, regularization = 'L1', draw=True)
res
# Out:
# К сожалению, мы не можем построить график, так как размерность пространства признаков велика.
# {'func': '-12.30258 + 0.0x1 + 0.32347x2 + 0.10478x3',
#  'weights': array([0.        , 0.32347429, 0.10477698]),
#  'bias': -12.30258097771531}

# %%
X, y = data[['X1', 'X4', 'X5', 'X3']], data['Y2']
res = lin_regression(X, y, regularization = 'L2', draw=True)
res
# Out:
# К сожалению, мы не можем построить график, так как размерность пространства признаков велика.
# {'func': '26.19183 + 0.0x1 + 0.02524x2 + 0.43249x3 + 0.0575x4',
#  'weights': array([0.        , 0.02523504, 0.43248786, 0.05750018]),
#  'bias': 26.19182796286703}

# %%
X, y = data[['X1', 'X2', 'X4']], data['Y1']
res = lin_regression(X, y, draw=True)
res
# Out:
# К сожалению, мы не можем построить график, так как размерность пространства признаков велика.
# {'func': '-1.63968 + 0.0x1 + 0.35619x2 -0.18951x3',
#  'weights': array([ 0.        ,  0.35618864, -0.1895065 ]),
#  'bias': -1.6396829885442417}

# %%
X, y = data[['X1', 'X2', 'X3', 'X4', 'X5']], data['Y2']

# %%
res = lin_regression(X.iloc[:, 1], y, regularization = 'L1', draw=True)
res
# Out:
# {'func': '50.17106 -0.05404x1',
#  'weights': array([-0.05403602]),
#  'bias': 50.17105872117893}

# %%
X, y = data[['X1', 'X2', 'X3', 'X4', 'X5']], data['Y1']

# %%
res = lin_regression(X.iloc[:, 1], y, regularization = 'L2', draw=True)
res
# Out:
# {'func': '-10.53155 + 0.34652x1',
#  'weights': array([0.34651607]),
#  'bias': -10.53154657839487}

# %%
X, y = data[['X1', 'X2', 'X3', 'X4', 'X5']], data['Y2']

# %%
res = lin_regression(X.iloc[:, 1], y, regularization = 'Student', draw=True)
res
# Out:
# {'func': '59.81413 -0.47551x1',
#  'weights': array([-0.47551386]),
#  'bias': 59.81413317756172}

# %%
X, y = data[['X1', 'X2', 'X3', 'X4', 'X5']], data['Y1']

# %%
res = lin_regression(X.iloc[:, 1], y, draw=True)
res
# Out:
# {'func': '-10.53158 + 0.34652x1',
#  'weights': array([0.3465201]),
#  'bias': -10.531576897638777}

# %% [markdown]
# #### 5. Точки соответствуют регрессии

# %%
data = pd.read_excel('Data.xlsx', sheet_name = '5л')
data.head(3)
# Out:
#     Y1      Y2     Y3  X1  X2  X3
# 0  1.0  117.05 -58.35   0 -73 -26
# 1  1.5  115.45 -53.99   1 -72 -24
# 2  2.0  113.85 -49.63   2 -71 -22

# %%
X, y = data[['X1', 'X2', 'X3']], data['Y1']

# %%
res = lin_regression(X.iloc[:, 0], y, regularization = 'L1', draw=True)
res
# Out:
# {'func': '1.15 + 0.49211x1',
#  'weights': array([0.49210526]),
#  'bias': 1.1500000000000004}

# %%
X, y = data[['X1', 'X2', 'X3']], data['Y2']

# %%
res = lin_regression(X.iloc[:, 1], y, regularization = 'L2', draw=True)
res
# Out:
# {'func': '0.26749 -1.59968x1',
#  'weights': array([-1.59967618]),
#  'bias': 0.26748633879782346}

# %%
X, y = data[['X1', 'X2', 'X3']], data['Y3']

# %%
# не может быть О_о
res = lin_regression(X.iloc[:, 2], y, regularization = 'Student', draw=True)
res
# Out:
# ---------------------------------------------------------------------------
# InsufficientData                          Traceback (most recent call last)
# <ipython-input-54-9885a420fd32> in <module>
#       1 # не может быть О_о
# ----> 2 res = lin_regression(X.iloc[:, 2], y, regularization = 'Student', draw=True)
#       3 res
#
# ~\Downloads\Aksen\regression.py in lin_regression(X, y, tol, regularization, alpha, draw)
#     202         X_new, y_new = student_del(pd.DataFrame(X),
#     203                                        pd.DataFrame(y_new))
# --> 204         check_data(X_new)
#     205         if len(X_new.shape) < 2:
#     206             X_new = X_new.to_numpy().reshape(-1, 1)
#
# ~\Downloads\Aksen\regression.py in check_data(X)
#      55     else:
#      56         if len(X) < 10:
# ---> 57             raise InsufficientData
#      58
#      59
#
# ...

# %%
res = lin_regression(X.iloc[:, 2], y, draw=True)
res
# Out:
# {'func': '-1.67 + 2.18x1',
#  'weights': array([2.18]),
#  'bias': -1.6700000000000088}

# %% [markdown]
# #### Окружность....

# %%
data = pd.read_excel('Data.xlsx', sheet_name = '8о')
data.head(3)
# Out:
#          Y1        Y2   X1
# 0  0.000000  5.000000 -4.0
# 1 -1.936492  3.063508 -3.5
# 2  1.936492  6.936492 -3.5

# %%
X, y = data['X1'], data['Y1']

# %%
res = lin_regression(X, y, regularization = 'L1', draw=True)
res
# Out:
# {'func': '0.0 + 0.0x1', 'weights': array([0.]), 'bias': 0.0}

# %%
res = lin_regression(X, y, regularization = 'L2', draw=True)
res
# Out:
# {'func': '0.0 -0.0x1', 'weights': array([-2.05359172e-17]), 'bias': 0.0}

# %%
res = lin_regression(X, y, regularization = 'Student', draw=True)
res
# Out:
# ---------------------------------------------------------------------------
# InsufficientData                          Traceback (most recent call last)
# <ipython-input-60-37f3eb5c5dc4> in <module>
# ----> 1 res = lin_regression(X, y, regularization = 'Student', draw=True)
#       2 res
#
# ~\Downloads\Aksen\regression.py in lin_regression(X, y, tol, regularization, alpha, draw)
#     202         X_new, y_new = student_del(pd.DataFrame(X),
#     203                                        pd.DataFrame(y_new))
# --> 204         check_data(X_new)
#     205         if len(X_new.shape) < 2:
#     206             X_new = X_new.to_numpy().reshape(-1, 1)
#
# ~\Downloads\Aksen\regression.py in check_data(X)
#      55     else:
#      56         if len(X) < 10:
# ---> 57             raise InsufficientData
#      58
#      59
#
# InsufficientData: Данных недостаточно. Их должно быть не менее 2^k строк, где k – количество признаков. Если признак 1, то хотя бы 10 строк.

# %%
res = lin_regression(X, y, draw=True)
res
# Out:
# {'func': '0.0 + 0.0x1', 'weights': array([0.]), 'bias': 0.0}
