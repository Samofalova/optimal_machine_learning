# %%
# !git clone https://github.com/Samofalova/optimal_machine_learning.git
# Out:
# Клонирование в «optimal_machine_learning»…
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 37 (delta 8), reused 0 (delta 0), pack-reused 0
# Получение объектов: 100% (37/37), 1.23 MiB | 2.80 MiB/s, готово.
# Определение изменений: 100% (8/8), готово.

# %%
get_ipython().run_line_magic('matplotlib', 'notebook')

# %%
from optimal_machine_learning.main.base_func_extrem import *

# %%
main()
# Out:
# Введите названия переменных (x y): x1 x2
# Введите функцию (y*x+2): 1/(1+x1**2)+1/(1+x2**2)
# Есть ли ограничения? (1 – да, 0 – нет): 0
# ((0, 0), 2, 'maximum')
# <img src="data:image/png;base64,..." width="640">

# %%
main()
# Out:
# Введите названия переменных (x y): x y
# Введите функцию (y*x+2): (-4*x + y**2)*exp(-x**2)
# Есть ли ограничения? (1 – да, 0 – нет): 1
# Введите ограничения для x [-10, 10]: [-2, 0]
# Введите ограничения для y [-10, 10]: [-10, 10]
# Если в списке критических точек есть комплексные числа, мы их не выводим.
# ((-sqrt(2)/2, 0), 2*sqrt(2)*exp(-1/2), 'saddle')
# <img src="data:image/png;base64,..." width="640">

# %%
data, points = get_extremums()
points
# Out:
# Введите названия переменных (x y): x y
# Введите функцию (y*x+2): exp(x+y)*(x**2-2*y**2)
# Есть ли ограничения? (1 – да, 0 – нет): 0
# [((-4, 2), 8*exp(-2), 'maximum'), ((0, 0), 0, 'saddle')]

# %%
show_chart(data, points)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data, points = get_extremums()
points
# Out:
# Введите названия переменных (x y): x y
# Введите функцию (y*x+2): (x**2 + 3*y**2)*exp(-(x**2+y**2))
# Есть ли ограничения? (1 – да, 0 – нет): 0
# [((-1, 0), exp(-1), 'saddle'),
#  ((0, -1), 3*exp(-1), 'maximum'),
#  ((0, 0), 0, 'minimum'),
#  ((0, 1), 3*exp(-1), 'maximum'),
#  ((1, 0), exp(-1), 'saddle')]

# %%
show_chart(data, points)
# Out:
# <img src="data:image/png;base64,..." width="640">
